# %% [markdown]
# # Step 1: Match voter file counts to ACS CVAP Counts

# %% [markdown]
# First, establish the "count" of registered voters in a given area.  I do this by narrowing to active voters only and those that are currently living at their address (per TargetSmart data).

# %%
#import dependencies
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Load .csv files- voter file data and acs data
# Unzip BlockGr file first
acs_data = "Resources/SLDU.csv"
vf_data = "Resources/az_statewide/az_statewide.csv"

# convert .csv data to Pandas dataframe
az_df = pd.read_csv(vf_data, encoding = "ISO-8859-1", dtype={'reg_census_id': object, 'vf_hd': object})
acs_cvap = pd.read_csv(acs_data, encoding = "ISO-8859-1")

# %%
az_df_count = az_df['voterbase_id'].count()
az_df_count
# Out:
# 4254481

# %%
#Building our list of current voters. First, narrow to just active voters
reg_voters = az_df.loc[az_df["vf_voter_status"] == "Active", :]
reg_voters_count = reg_voters['voterbase_id'].count()
reg_voters_count
# Out:
# 3770894

# %%
#Then, narrow to just those voters with a street level geocode
geo_voters = reg_voters.loc[reg_voters["reg_level"] == "Street", :]
geo_voters_count = geo_voters['voterbase_id'].count()
geo_voters_count
# Out:
# 3632837

# %%
#Then, remove voters who are no longer living at their current address (according to targetsmart data)
#This will be the list the count of voters we compare to ACS CVAP data
vf_df = geo_voters.loc[geo_voters["voterbase_mover_status"] == "Resides at Current Address", :]
vf_count = vf_df['voterbase_id'].count()
vf_count
# Out:
# 3141632

# %%
# convert reg_census_id to string, create new census block group column and state fips column from reg_census_id
vf_df.reg_census_id = vf_df.reg_census_id.astype(str)
vf_df['block_group'] = vf_df.reg_census_id.str[:12]
vf_df['state_fips'] = vf_df.reg_census_id.str[:2]
# Out:
# C:\Users\chris.brill\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Users\chris.brill\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chris.brill\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# insert check to make sure just records with An Arizona census block are making it through (AZ FIPS code = 04)
az_df = vf_df.loc[vf_df["state_fips"] == "04", :]
az_count = az_df['voterbase_id'].count()
az_count
# Out:
# 3141630

# %%
az_df.head()
# Out:
#          voterbase_id vf_voter_status vf_county_name vf_hd reg_level  \
# 4887  AZ-000000562269          Active       MARICOPA   027    Street
# 4889       AZ-6734255          Active       MARICOPA   027    Street
# 4891  AZ-000000554541          Active       MARICOPA   027    Street
# 4893       AZ-6941812          Active       MARICOPA   024    Street
# 4894       AZ-5340916          Active       MARICOPA   024    Street
#
#         reg_census_id      voterbase_mover_status  tsmr_race   block_group  \
# 4887  040131149001045  Resides at Current Address   Hispanic  040131149001
# 4889  040131142001057  Resides at Current Address   Hispanic  040131142001
# 4891  040131142001053  Resides at Current Address   Hispanic  040131142001
# 4893  040131131001008  Resides at Current Address  Caucasian  040131131001
# 4894  040131131001001  Resides at Current Address  Caucasian  040131131001
#
#      state_fips
# 4887         04
# 4889         04
# 4891         04
# 4893         04
# 4894         04

# %%
# Registered voters by leg district
ld_counts = az_df["vf_hd"].value_counts()
reg_table = pd.DataFrame({"reg_count": ld_counts,
                                 })
reg_table.head(30)
# Out:
#      reg_count
# 012     140710
# 023     138009
# 022     134009
# 001     131697
# 018     126867
# 015     124272
# 017     123756
# 011     123712
# 028     117078
# 006     115273
# 025     113704
# 013     112450
# 009     111821
# 010     111818
# 016     111801
# 021     109824
# 014     108354
# 020     108090
# 005     107660
# 024      94733
# 002      92723
# 003      86757
# 027      85084
# 008      83464
# 004      82773
# 026      82219
# 019      78621
# 029      72177
# 030      70497
# 007      34361

# %%
az_cvap = acs_cvap[acs_cvap['GEONAME'].str.contains("Arizona")]
az_cvap['LD'] = az_cvap['GEOID'].str[9:]
az_cvap = az_cvap.rename(columns={'CVAP_EST': 'CVAP_estimate',
                                   'CVAP_MOE': 'CVAP_margin_of_error',
                                   })
az_cvap = az_cvap.loc[az_cvap["LNTITLE"] == "Total", :]
az_cvap
# Out:
# C:\Users\chris.brill\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                
# 988          1   234255     2358   185220     1891   227230     2323
# 1001         1   231800     1603   193500     1620   221435     1745
# 1014         1   225150     3441   178870     2489   196075     3222
# 1027         1   238940     2558   184515     1936   224680     2842
# 1040         1   234190     2713   185085     1948   199125     2739
# 1053         1   224955     3425   156680     2433   192995     3250
# 1066         1   231085     3026   181405     2058   208345     3052
# 1079         1   241025     4003   160970     2561   194205     3477
# 1092         1   218935     3626   153365     2213   175200     3137
#
#       CVAP_estimate  CVAP_margin_of_error   LD
# 715          177575                  2243  001
# 728          133670                  1632  002
# 741          145110                  2615  003
# 754          128470                  2268  004
# 767          175075                  1034  005
# 780          174330                  1809  006
# 793          142200                  1194  007
# 806          154105                  2069  008
# 819          161040                  1994  009
# 832          162330                  2077  010
# 845          165255                  2148  011
# 858          166315                  1781  012
# 871          161080                  2541  013
# 884          156850                  1157  014
# 897          163830                  2088  015
# 910          180570                  2815  016
# 923          156055                  1764  017
# 936          170005                  2165  018
# 949          125560                  2170  019
# 962          166305                  2146  020
# 975          167760                  1889  021
# 988          178815                  1847  022
# 1001         183790                  1786  023
# 1014         152160                  2417  024
# 1027         171175                  2247  025
# 1040         152105                  2373  026
# 1053         126500                  2234  027
# 1066         160545                  1988  028
# 1079         117615                  2291  029
# 1092         113970                  2023  030

# %%
#az_cvap = az_cvap.drop(columns=['GEONAME', 'LNTITLE', 'GEOID', 'CIT_EST', 'CIT_MOE', 'TOT_EST', 'ADU_EST', 'ADU_MOE' ])
az_cvap = az_cvap[["LD","CVAP_estimate"]]
az_cvap.set_index('LD')
az_cvap.head()
# Out:
#       LD  CVAP_estimate
# 715  001         177575
# 728  002         133670
# 741  003         145110
# 754  004         128470
# 767  005         175075

# %%
# Combine ACS CVAP count with voter file registration count by census block group
merged_data = pd.merge(reg_table, az_cvap, left_index=True, right_on='LD')
merged_data = merged_data[["LD", "CVAP_estimate", "reg_count"]]
merged_data.set_index('LD')
merged_data.sort_values(by=['LD'])
merged_data.head(30)
# Out:
#        LD  CVAP_estimate  reg_count
# 858   012         166315     140710
# 1001  023         183790     138009
# 988   022         178815     134009
# 715   001         177575     131697
# 936   018         170005     126867
# 897   015         163830     124272
# 923   017         156055     123756
# 845   011         165255     123712
# 1066  028         160545     117078
# 780   006         174330     115273
# 1027  025         171175     113704
# 871   013         161080     112450
# 819   009         161040     111821
# 832   010         162330     111818
# 910   016         180570     111801
# 975   021         167760     109824
# 884   014         156850     108354
# 962   020         166305     108090
# 767   005         175075     107660
# 1014  024         152160      94733
# 728   002         133670      92723
# 741   003         145110      86757
# 1053  027         126500      85084
# 806   008         154105      83464
# 754   004         128470      82773
# 1040  026         152105      82219
# 949   019         125560      78621
# 1079  029         117615      72177
# 1092  030         113970      70497
# 793   007         142200      34361

# %%
#calculate the percent of each LD that is registered
merged_data['reg_potential'] = merged_data.CVAP_estimate - merged_data.reg_count
merged_data['percent_reg'] = merged_data.reg_count / merged_data.CVAP_estimate

# %%
#sort data on registration potential
merged_data.sort_values("reg_potential", inplace=True, ascending=False)
merged_data.head(25)

cm = sns.light_palette("green", as_cmap=True)

final_table= merged_data.style.background_gradient(cmap=cm)

final_table
# Out:
# <style  type="text/css" >
#     #T_7391158c_a3ff_11e9_a385_0c54151efc66row0_col1 {
#             background-color:  #89cc89;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row0_col3 {
#             background-color:  #008000;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row1_col1 {
#             background-color:  #61b661;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row1_col2 {
#             background-color:  #7bc47b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row1_col3 {
#             background-color:  #67b967;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row1_col4 {
#             background-color:  #73c073;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row2_col1 {
#             background-color:  #68ba68;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row2_col2 {
#             background-color:  #7ec67e;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row2_col3 {
#             background-color:  #6abb6a;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row2_col4 {
#             background-color:  #74c074;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row3_col1 {
#             background-color:  #0a850a;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row3_col2 {
#             background-color:  #3ea23e;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row3_col3 {
#             background-color:  #6dbc6d;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row3_col4 {
#             background-color:  #56b056;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row4_col1 {
#             background-color:  #1c8f1c;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row4_col2 {
#             background-color:  #47a747;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row4_col3 {
#             background-color:  #70be70;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row4_col4 {
#             background-color:  #57b057;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row5_col1 {
#             background-color:  #1f911f;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row5_col2 {
#             background-color:  #379e37;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row5_col3 {
#             background-color:  #88cb88;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row5_col4 {
#             background-color:  #46a746;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row6_col1 {
#             background-color:  #7fc67f;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row6_col2 {
#             background-color:  #74c074;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row6_col3 {
#             background-color:  #8bcd8b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row6_col4 {
#             background-color:  #5eb45e;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row7_col1 {
#             background-color:  #3aa03a;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row7_col2 {
#             background-color:  #46a746;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row7_col3 {
#             background-color:  #8bcd8b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row7_col4 {
#             background-color:  #4ba94b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row8_col1 {
#             background-color:  #349d34;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row8_col2 {
#             background-color:  #43a543;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row8_col3 {
#             background-color:  #8bcd8b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row8_col4 {
#             background-color:  #49a849;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row9_col1 {
#             background-color:  #299729;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row9_col2 {
#             background-color:  #3aa03a;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row9_col3 {
#             background-color:  #8cce8c;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row9_col4 {
#             background-color:  #44a644;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row10_col1 {
#             background-color:  #67b967;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row10_col2 {
#             background-color:  #63b763;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row10_col3 {
#             background-color:  #8cce8c;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row10_col4 {
#             background-color:  #55af55;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row11_col1 {
#             background-color:  #46a746;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row11_col2 {
#             background-color:  #3ea23e;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row11_col3 {
#             background-color:  #a0d9a0;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row11_col4 {
#             background-color:  #3ba13b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row12_col1 {
#             background-color:  #4ba94b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row12_col2 {
#             background-color:  #3ea23e;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row12_col3 {
#             background-color:  #a4dba4;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row12_col4 {
#             background-color:  #3aa03a;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row13_col1 {
#             background-color:  #4ba94b;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row13_col2 {
#             background-color:  #3da23d;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row13_col3 {
#             background-color:  #a6dca6;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row13_col4 {
#             background-color:  #389f38;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row14_col1 {
#             background-color:  #58b158;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row14_col2 {
#             background-color:  #45a645;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row14_col3 {
#             background-color:  #a6dca6;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row14_col4 {
#             background-color:  #3aa03a;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row15_col1 {
#             background-color:  #c0eac0;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row15_col2 {
#             background-color:  #86ca86;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row15_col3 {
#             background-color:  #aadeaa;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row15_col4 {
#             background-color:  #54ae54;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row16_col1 {
#             background-color:  #148b14;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row16_col2 {
#             background-color:  #138a13;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row16_col3 {
#             background-color:  #ade0ad;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row16_col4 {
#             background-color:  #289628;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row17_col1 {
#             background-color:  #008000;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row17_col2 {
#             background-color:  #058305;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row17_col3 {
#             background-color:  #aee0ae;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row17_col4 {
#             background-color:  #249424;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row18_col1 {
#             background-color:  #b6e5b6;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row18_col2 {
#             background-color:  #7dc57d;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row18_col3 {
#             background-color:  #aee0ae;
#         }    #T_7391158c_a3ff_11e9_a385_0c54151efc66row18_col4 {
#             background-color:  #4daa4d;
#         }    #T_7391158c_a3ff_11e9_a385_0c5

# %%
# Export file as a CSV
merged_data.to_csv("Output/statewide_reg_analysis.csv", index=False, header=True)
